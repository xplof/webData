# %%
import pandas as pd
data = {
   '이름':['홍길동','유관순','이순신','강감찬','김구','김유신','홍길자','홍길순'],
   '학교':['가산고','가산고','가산고','가산고','가산고','디지털고','디지털고','디지털고'],
   '키':[197,184,168,187,188,202,188,190],
   '국어':[90,40,80,40,15,80,55,100],
   '영어':[85,35,75,60,20,100,65,85],
   '수학':[100,50,70,70,10,95,45,90],
   '과학':[95,55,80,75,35,85,40,95],
   '사회':[85,25,75,80,10,80,35,95],
   'SW특기':['Python','Java','Javascript','','','C','PYTHON','C#']
}
df=pd.DataFrame(data)
df.index=[1,2,3,4,5,6,7,8]
df.index.name='지원번호'

# %%
# 파일저장
df.to_csv('score.csv',encoding='utf-8-sig')

# %%
# 파일저장 index제외
# df.to_csv('score2.csv',encoding='utf-8-sig',index=False)
df.to_csv('score2.csv', encoding='utf-8-sig',index=False)

# %%
df.to_csv('score.txt',sep='\t', encoding='utf8')

# %%
df.to_excel('score.xlsx')

# %% [markdown]
# # 파일읽어오기

# %%
df=pd.read_excel('score.xlsx')
df
# Out:
#    지원번호   이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 0     1  홍길동   가산고  197   90   85  100  95  85      Python
# 1     2  유관순   가산고  184   40   35   50  55  25        Java
# 2     3  이순신   가산고  168   80   75   70  80  75  Javascript
# 3     4  강감찬   가산고  187   40   60   70  75  80         NaN
# 4     5   김구   가산고  188   15   20   10  35  10         NaN
# 5     6  김유신  디지털고  202   80  100   95  85  80           C
# 6     7  홍길자  디지털고  188   55   65   45  40  35      PYTHON
# 7     8  홍길순  디지털고  190  100   85   90  95  95          C#

# %%
# df=pd.read_csv('score.csv',skiprows=1) #row 1개 제외
# df=pd.read_csv('score.csv',skiprows=[1,3,5]) #row 1,3,5번 제외
df=pd.read_csv('score.csv',skiprows=2,nrows=5) #row 2개 제외, 총5개
df
# Out:
#    2  유관순   가산고  184  40   35  50  55  25        Java
# 0  3  이순신   가산고  168  80   75  70  80  75  Javascript
# 1  4  강감찬   가산고  187  40   60  70  75  80         NaN
# 2  5   김구   가산고  188  15   20  10  35  10         NaN
# 3  6  김유신  디지털고  202  80  100  95  85  80           C
# 4  7  홍길자  디지털고  188  55   65  45  40  35      PYTHON

# %%
df=pd.read_excel('people.xlsx',skiprows=2,nrows=2)
df
# Out:
# c:\python3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#        행정기관코드     행정기관        총인구수         세대수  세대당 인구      남자 인구수  \
# 0  1000000000     전국    51,175,725  24,212,185    2.11  25,474,633
# 1  1100000000  서울특별시     9,331,860   4,498,689    2.07   4,501,804
#
#        여자 인구수  남여 비율
# 0  25,701,092   0.99
# 1   4,830,056   0.93

# %%
df=pd.read_excel('people2.xlsx',skiprows=3)
df
# Out:
# c:\python3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#         행정기관코드       행정기관       총 인구수     연령구간인구수       0~9세     10~19세  \
# 0            0       전국    51,175,725  51,175,725  3,069,919  4,623,300
# 1   1100000000    서울특별시     9,331,860   9,331,860    474,899    722,637
# 2   2600000000    부산광역시     3,256,408   3,256,408    177,078    263,768
# 3   2700000000    대구광역시     2,359,159   2,359,159    139,485    212,611
# 4   2800000000    인천광역시     3,033,844   3,033,844    193,082    274,262
# 5   2900000000    광주광역시     1,400,827   1,400,827     90,086    144,499
# 6   3000000000    대전광역시     1,439,393   1,439,393     89,507    136,106
# 7   3100000000    울산광역시     1,094,460   1,094,460     70,892    108,973
# 8   3600000000  세종특별자치시       391,992     391,992     40,594     53,025
# ...

# %%
# index col = 행정기관을 index로 지정
# skiprows 제외후 가져오기
# nrows 해당개수만큼 가져오기
# usecols 해당되는 컬럼을 가져오기
df=pd.read_excel('people2.xlsx',skiprows=3,index_col='행정기관')
df
# Out:
# c:\python3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                행정기관코드       총 인구수     연령구간인구수       0~9세     10~19세  \
# 행정기관
# 전국                  0  51,175,725  51,175,725  3,069,919  4,623,300
# 서울특별시      1100000000   9,331,860   9,331,860    474,899    722,637
# 부산광역시      2600000000   3,256,408   3,256,408    177,078    263,768
# 대구광역시      2700000000   2,359,159   2,359,159    139,485    212,611
# 인천광역시      2800000000   3,033,844   3,033,844    193,082    274,262
# 광주광역시      2900000000   1,400,827   1,400,827     90,086    144,499
# 대전광역시      3000000000   1,439,393   1,439,393     89,507    136,106
# 울산광역시      3100000000   1,094,460   1,094,460     70,892    108,973
# 세종특별자치시    3600000000     391,992     391,992     40,594     53,025
# 경기도        4100000000  13,702,756  13,702,756    920,385  1,320,363
# ...

# %%
df=pd.read_excel('people3.xlsx',skiprows=3, index_col='행정기관',nrows=1,usecols='b,e:p')
df
# Out:
#            0~9세     10~19세     20~29세     30~39세     40~49세     50~59세  \
# 행정기관
# 전국    3,140,118  4,619,265  5,955,656  6,624,563  7,722,823  8,706,370
#
#          60~69세     70~79세     80~89세   90~99세 100세 이상       남 인구수
# 행정기관
# 전국    7,818,783  4,186,597  2,104,544  329,925   8,577  25,498,324
