# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family']='Malgun Gothic' #windows
matplotlib.rcParams['font.size']=15 #windows

# %%
x=[1,2,3]
y=[2,4,8]

# %%
plt.plot(x,y) #꺾은선 그래프

# %%
plt.bar(x,y) #막대그래프
plt.title('chart')
# Out:
# Text(0.5, 1.0, 'chart')
