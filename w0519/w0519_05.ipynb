# %%
import pandas as pd

# 데이터 읽어오기
df = pd.read_excel('data/F000801_20250519145719399_excel.xlsx',skiprows=2)
df
# Out:
# c:\python3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    Unnamed: 0    Unnamed: 1     2015     2016     2017     2018     2019  \
# 0          전체           NaN  438,420  406,243  357,771  326,822  302,676
# 1       모 연령별        15세 미만       16       15        6        8       10
# 2         NaN      15 - 19세    2,211    1,907    1,520    1,292    1,096
# 3         NaN      20 - 24세   20,514   19,078   15,768   13,313   11,303
# 4         NaN      25 - 29세   94,622   85,036   74,026   65,029   57,834
# 5         NaN      30 - 34세  216,252  192,968  161,045  143,067  131,334
# 6         NaN      35 - 39세   92,081   94,313   92,645   91,101   87,300
# 7         NaN      40 - 44세   12,138   12,336   12,202   12,417   13,242
# 8         NaN      45 - 49세      335      371      373      389      398
# ...
