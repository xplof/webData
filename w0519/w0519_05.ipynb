# %%
import pandas as pd

# 데이터 읽어오기
df = pd.read_excel('data/H000202_20250519145337168_excel.xlsx')
# Out:
# c:\python3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#   통계표명:                       출생아수 및 조출생률 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0   단위:                       명, 인구 천명당 명        NaN        NaN        NaN
# 1   NaN                              2015       2016       2017       2018
# 2  출생아수                           438,420    406,243    357,771    326,822
# 3    남자                           224,906    208,064    184,308    167,686
# 4    여자                           213,514    198,179    173,463    159,136
# 5  조출생률                               8.6        8.0        7.0        6.4
# 6   출처:                     통계청, 「인구동향조사」        NaN        NaN        NaN
# 7   주석:  국내 및 해외출생 포함(단, 출생 이후 국내 거주만 해당)        NaN        NaN        NaN
# 8   NaN                        2024년은 잠정임        NaN        NaN        NaN
#
# ...
